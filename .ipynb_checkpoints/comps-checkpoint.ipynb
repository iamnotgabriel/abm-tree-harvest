# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use("seaborn")

# %%
borges = pd.read_csv("borges/borgespp.csv")
canneti = pd.read_csv("canneti/cannetipp.csv")
oliveira = pd.read_csv("oliveira/oliveirapp.csv")
braz = pd.read_csv("braz_2017/braz_2017pp.csv")
display(borges.head(2))
display(canneti.head(2))
display(braz.head(2))
display(oliveira.head(2))
# Out:
#    class1  class2  class3  class4  class5  class6  class7  class8  class9  \
# 0   981.0  1508.0   215.0  1117.0  2017.0  1515.0   976.0   345.0  1139.0
# 1   471.0  1344.0   708.0   714.0  1639.0  1723.0  1110.0   721.0  1383.0
#
#    trees_cut  trees_reman  trees_seeds
# 0     3201.0       3194.0          714
# 1     4026.0       2450.0          814
#    class1  class2  class3  class4  class5  class6  class7  class8  class9  \
# 0   981.0  1508.0   215.0  1117.0  2017.0  1515.0   976.0   345.0  1139.0
# 1   471.0  1261.0   791.0   714.0  1639.0  1723.0  1108.0   707.0  1399.0
#
#    trees_cut  trees_reman  trees_seeds
# 0     3201.0       3194.0          714
# 1     4026.0       2450.0          814
#    class1  class2  class3  class4  class5  class6  class7  class8  class9  \
# 0   981.0  1508.0   215.0  1117.0  2017.0  1515.0   976.0   345.0  1139.0
# 1   471.0  1344.0   708.0   714.0  1361.0  1831.0  1269.0   711.0  1404.0
#
#    trees_cut  trees_reman  trees_seeds
# 0     3201.0       3194.0          714
# 1     4265.0       2178.0          847
#    class1  class2  class3  class4  class5  class6  class7  class8  class9  \
# 0   981.0  1508.0   215.0  1117.0  2017.0  1515.0   976.0   345.0  1139.0
# 1   426.0  1128.0   965.0   359.0  1514.0  1726.0  1250.0   981.0  1464.0
#
#    trees_cut  trees_reman  trees_seeds
# 0     3201.0       3194.0          714
# 1     4439.0       1984.0          871

# %%
borges.loc[9,:].values
# Out:
# array([   0.,    0.,   10.,   46.,  311.,  781.,  773., 1111., 6781.,
#        7192., 1337., 1274.])

# %%
df = pd.DataFrame({
    "borges":borges.loc[9,:].values,
    "oliveira":oliveira.loc[9,:].values,
    "braz":braz.loc[9,:].values,
    "canneti":canneti.loc[9,:].values},
    index=[i for i in range(1, 13)])
df
# Out:
#     borges  oliveira    braz  canneti
# 1      0.0       0.0     0.0      0.0
# 2      0.0       0.0     0.0      0.0
# 3     10.0       0.0    10.0      8.0
# 4     46.0       0.0    46.0     43.0
# 5    311.0      43.0   178.0    311.0
# 6    781.0     121.0   436.0    781.0
# 7    773.0     251.0   704.0    773.0
# 8   1111.0     404.0   897.0    880.0
# 9   6781.0    8994.0  7542.0   7017.0
# 10  7192.0    7188.0  7190.0   7195.0
# 11  1337.0    1313.0  1319.0   1334.0
# 12  1274.0    1312.0  1294.0   1276.0

# %%
for col in df:
    df[col] = df[col] / df[col].sum()
df
# Out:
#       borges  oliveira      braz   canneti
# 1   0.000000  0.000000  0.000000  0.000000
# 2   0.000000  0.000000  0.000000  0.000000
# 3   0.000510  0.000000  0.000510  0.000408
# 4   0.002345  0.000000  0.002345  0.002192
# 5   0.015854  0.002191  0.009074  0.015853
# 6   0.039814  0.006165  0.022227  0.039810
# 7   0.039407  0.012789  0.035889  0.039403
# 8   0.056637  0.020585  0.045728  0.044857
# 9   0.345687  0.458270  0.384482  0.357682
# 10  0.366639  0.366249  0.366538  0.366755
# 11  0.068159  0.066901  0.067241  0.067999
# 12  0.064947  0.066850  0.065967  0.065042

# %%
fig, ax = plt.subplots(2, 2, constrained_layout=True)

ax[0][0].bar([str(i) for i in range(1,10)], height =df.loc[:9,"borges"])
ax[0][0].set_title("Borges")

ax[0][1].bar([str(i) for i in range(1,10)], height =df.loc[:9,"canneti"])
ax[0][1].set_title("Canneti")

ax[1][0].bar([str(i) for i in range(1,10)], height =df.loc[:9,"oliveira"], color = "red")
ax[1][0].set_title("Oliveira")

ax[1][1].bar([str(i) for i in range(1,10)], height =df.loc[:9,"braz"], color = "red")
ax[1][1].set_title("Braz(2017)")

plt.savefig("crescimento_comppp", dpi= 300)
plt.show()

# %%
fig, ax = plt.subplots(2, 2, constrained_layout=True)

ax[0][0].bar([str(i) for i in range(1,9)], height =df.loc[:8,"borges"])
ax[0][0].set_title("Borges")

ax[0][1].bar([str(i) for i in range(1,9)], height =df.loc[:8,"canneti"])
ax[0][1].set_title("Canneti")

ax[1][0].bar([str(i) for i in range(1,9)], height =df.loc[:8,"oliveira"], color = "red")
ax[1][0].set_title("Oliveira")

ax[1][1].bar([str(i) for i in range(1,9)], height =df.loc[:8,"braz"], color = "red")
ax[1][1].set_title("Braz(2017)")

plt.savefig("crescimento_comp_ajspp", dpi = 300)
plt.show()
