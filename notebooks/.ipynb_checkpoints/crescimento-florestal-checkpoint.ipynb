# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use("seaborn")

# %%
media = pd.read_csv("../dados/output/classes-borges-gouveia.csv")
media = pd.read_csv("../dados/output/classes-mean-gouveia.csv")
positivo = pd.read_csv("../dados/output/classes-oliveira-gouveia.csv")
display(positivo.head(3))
display(media.head(3))
display(media.head(3))
# Out:
#    all_trees       class1       class2      class3       class4       class5  \
# 0       9813   981.000000  1508.000000  215.000000  1117.000000  2017.000000
# 1       8073  1887.973537  1607.768578  343.391420   232.643895  1116.989001
# 2       8881  2471.763382  2392.555608  877.937003   101.037722   297.460111
#
#         class6      class7     class8       class9  nao_comerc  proib_cort  \
# 0  1515.000000  976.000000  345.00000  1139.000000  156.000000   17.000000
# 1  1431.880920  497.223000  367.70000   623.040000  109.343357   12.927943
# 2   796.477873  884.510985  380.41973   728.711072  130.792318   16.531174
#
#      trees_cut  trees_reman  trees_seeds
# 0  3701.000000  3210.000000          693
# 1  2248.172798  1289.996614          570
# 2  1797.939716   634.517855          509
#    all_trees       class1       class2      class3       class4       class5  \
# 0       9813   981.000000  1508.000000  215.000000  1117.000000  2017.000000
# 1       8060  2339.373842  1254.753883  278.122400   387.102652  1096.976591
# 2       8858  3363.183946  1955.696259  465.968285   133.508833   395.080139
#
#         class6      class7      class8       class9  nao_comerc  proib_cort  \
# 0  1515.000000  976.000000  345.000000  1139.000000  156.000000   17.000000
# 1  1358.106984  496.534000  293.080000   604.560000  109.343357   12.927943
# 2   893.277698  764.865239  317.187452   640.781542  132.750034   16.665789
#
#      trees_cut  trees_reman  trees_seeds
# 0  3701.000000  3210.000000          693
# 1  2145.574217  1370.595195          560
# 2  1745.711319   691.180236          498
#    all_trees       class1       class2      class3       class4       class5  \
# 0       9813   981.000000  1508.000000  215.000000  1117.000000  2017.000000
# 1       8064  2349.258520  1289.728965  234.986180   458.489188  1288.724059
# 2       8870  3387.217372  2033.408573  370.031481   165.501044   593.199218
#
#         class6      class7      class8       class9  nao_comerc  proib_cort  \
# 0  1515.000000  976.000000  345.000000  1139.000000  156.000000   17.000000
# 1  1166.809440  471.234000  282.200000   567.180000  109.343357   12.927943
# 2   907.306096  602.455551  320.832319   550.005151  132.259110   16.281174
#
#      trees_cut  trees_reman  trees_seeds
# 0  3701.000000  3210.000000          693
# 1  1901.230015  1636.939396          527
# 2  1659.457374   833.643054          477

# %%
display(positivo.tail(3))
display(media.tail(3))
# Out:
#    all_trees       class1       class2       class3       class4       class5  \
# 7      10448  2592.774565  2589.436602  1348.334843  1047.740420  1028.759606
# 8      11536  2870.100814  2806.650601  1322.881762   948.984393  1065.365101
# 9      12695  2985.345495  2960.920193  1467.535986  1035.293052  1018.437202
#
#        class6      class7      class8       class9  nao_comerc  proib_cort  \
# 7  796.014519  312.815190  142.752295   852.851990  151.040084   23.019214
# 8  895.258873  614.133488  303.449025   948.821118  168.247403   25.357316
# 9  960.406791  724.069626  608.734850  1189.883712  190.843244   28.051527
#
#      trees_cut  trees_reman  trees_seeds
# 7  1540.716880  1807.786890          453
# 8  2083.542009  1791.962789          498
# 9  2728.162260  1857.821577          559
#    all_trees       class1       class2       class3       class4      class5  \
# 7      11288  3828.465835  3093.618821  1518.794291  1081.295019  652.901597
# 8      12432  4092.409547  3293.485564  1608.492800  1216.350811  823.802488
# 9      13676  4344.333322  3534.390104  1726.516523  1331.938210  978.843613
#
#        class6      class7      class8      class9  nao_comerc  proib_cort  \
# 7  325.241826  157.573405  170.480665  621.625061  158.440063   23.335036
# 8  472.356131  227.342775  180.976077  684.502395  176.469715   26.139981
# 9  631.993371  331.888305  226.098694  759.958894  202.461017   29.487989
#
#      trees_cut  trees_reman  trees_seeds
# 7   818.615080  1481.611641          341
# 8  1092.060583  1758.002490          393
# 9  1466.755555  2003.571471          441

# %%
positivo["sem_destino"] = positivo["all_trees"] - (positivo["trees_cut"] + positivo["trees_reman"] + positivo["trees_seeds"])
positivo["sem_destino"]
# Out:
# 0    2209.000000
# 1    3939.902088
# 2    5911.323545
# 3    6354.003342
# 4    6138.440005
# 5    6405.144458
# 6    6784.997208
# 7    6646.496230
# 8    7162.495203
# 9    7550.016163
# Name: sem_destino, dtype: float64

# %%
negativo["sem_destino"] = negativo["all_trees"] - (negativo["trees_cut"] + negativo["trees_reman"] + negativo["trees_seeds"])
negativo["sem_destino"]
# Out:
# 0    2209.000000
# 1    3998.830588
# 2    5899.899572
# 3    6855.454015
# 4    7312.384968
# 5    7881.517346
# 6    8412.070915
# 7    8794.849508
# 8    9321.991134
# 9    9903.466221
# Name: sem_destino, dtype: float64

# %%
media["sem_destino"] = media["all_trees"] - (media["trees_cut"] + media["trees_reman"] + media["trees_seeds"])
media["sem_destino"]
# Out:
# 0    2209.000000
# 1    3983.830588
# 2    5923.108445
# 3    6798.988184
# 4    7231.295977
# 5    7648.062416
# 6    8093.084934
# 7    8367.247005
# 8    8837.490161
# 9    9366.907815
# Name: sem_destino, dtype: float64

# %%
plt.bar(positivo.columns[1:10], positivo.loc[9,"class1":"class9"])
plt.title("Distribuição final de árvores (positivo)", fontdict={"fontsize":18})
plt.tick_params(axis='both', which='major', labelsize=12)
plt.savefig("positivo-class-final.png")
plt.show()

# %%
plt.bar(positivo.columns[10:], positivo.loc[9,"nao_comerc":])
plt.title("Árvores por destino(positivo)", fontdict={"fontsize":18})
plt.tick_params(axis='both', which='major', labelsize=12)
plt.savefig("positivo-dest-final.png")
plt.show()

# %%
ida = pd.read_csv("ida-data.csv")
ida["Média"] = ida.mean(axis=1)
lines = ida[["Oliveira", "Média", "Borges"]].values
plt.plot(range(1, 10), lines)
plt.legend(["Lento", "Acelerado", "Médio"])
plt.title("IDA dos cenários de exploração")
plt.savefig("ida-cenarios.png", dpi= 250)
plt.show()
ida
# Out:
#    Canneti  Braz_2012  Braz_2014  Braz_2015  Braz_2017  Oliveira  Castro  \
# 0    0.283        NaN      0.438        NaN      0.291     0.427   0.233
# 1    0.377      0.443      0.438      0.522      0.317     0.606   0.233
# 2    0.451      0.348      0.438      0.315      0.442     0.720   0.233
# 3    0.475      0.514      0.438      0.823      0.473     0.802   0.233
# 4    0.485      0.562      0.438      1.256      0.623     0.710   0.233
# 5    0.493      0.670      0.438      0.931      0.587     0.751   0.233
# 6    0.569      0.738      0.438      0.895      0.587     0.903   0.233
# 7    0.580      1.042      0.438      0.852      0.717     0.816   0.233
# 8    0.546      1.157      0.438      0.754      0.836     0.838   0.233
#
#    Borges     Média
# 0   0.287  0.326500
# 1   0.325  0.407625
# 2   0.437  0.423000
# 3   0.452  0.526250
# 4   0.470  0.597125
# 5   0.478  0.572625
# 6   0.531  0.611750
# 7   0.417  0.636875
# 8     NaN  0.686000

# %%
f, ax = plt.subplots()
index = np.arange(1, 10)
width = 0.3
ax.bar(index-width, positivo.iloc[9, 1:10].values, label= "Positivo", width = width)
ax.bar(index, media.iloc[9, 1:10].values, label= "Média", width = width)
ax.bar(index + width, negativo.iloc[9, 1:10].values, label= "Negativo", width = width)
plt.xticks(index)
plt.title("Comparação da distribuição final", fontdict={"fontsize":18, "fontweight":"bold"})
plt.xlabel("Classes", fontdict={"fontsize":16})
plt.ylabel("Árvores",fontdict={"fontsize":16})
plt.legend()
plt.savefig("destfinal-comp.png", dpi=250)
plt.show()

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 6))
plt.suptitle("Árvores por destino", fontdict={"fontsize":20,"fontweight":"bold"})
ax1.bar(positivo.columns[10:-1], positivo.loc[9,"nao_comerc":"trees_seeds"])
ax1.set_title("Positivo", fontdict={"fontsize":15})
ax2.bar(media.columns[10:-1], positivo.loc[9,"nao_comerc":"trees_seeds"])
ax2.set_title("media", fontdict={"fontsize":15})
plt.tick_params(axis='both', which='major', labelsize=12)
plt.savefig("positivo-dest-final-comp.png")
plt.show()

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 6))
plt.suptitle("Árvores por destino", fontdict={"fontsize":20,"fontweight":"bold"})
ax1.bar(positivo.columns[10:], positivo.loc[9,"nao_comerc":])
ax1.set_title("Positivo", fontdict={"fontsize":15})
ax2.bar(media.columns[10:], positivo.loc[9,"nao_comerc":])
ax2.set_title("media", fontdict={"fontsize":15})
plt.tick_params(axis='both', which='major', labelsize=12)
plt.savefig("positivo-dest-final-comp2.png")
plt.show()

# %%
plt.bar(media.columns[1:10], media.loc[9,"class1":"class9"])
plt.title("Distribuição final de árvores(media)", fontdict={"fontsize":18})
plt.tick_params(axis='both', which='major', labelsize=12)
plt.savefig("media-class-final.png")
plt.show()

# %%
plt.bar(media.columns[10:], media.loc[9,"nao_comerc":])
plt.title("Árvores por destino", fontdict={"fontsize":18})
plt.tick_params(axis='both', which='major', labelsize=12)
plt.savefig("negavito-dest-final.png")
plt.show()

# %%
fig, ax = plt.subplots(3, 3)
fig.tight_layout(pad=1.0)
fig.suptitle("Distribuição das classes diamétricas", x = 0.5, y=1.05)
for row in range(1, 10):
    ax[(row-1)//3][(row-1)%3].bar(positivo.columns[1:10], positivo.loc[row,"class1":"class9"], color = ["blue"] *5 + ["red"] *4)
    ax[(row-1)//3][(row-1)%3].title.set_text(f't={row}')
    ax[(row-1)//3][(row-1)%3].get_xaxis().set_visible(False)
plt.savefig("positivo-dist-all.png")
plt.show()

# %%
fig, ax = plt.subplots(3, 3)
fig.tight_layout(pad=1.0)
fig.suptitle("Distribuição das classes diamétricas", x = 0.5, y=1.05)
for row in range(1, 10):
    ax[(row-1)//3][(row-1)%3].bar(media.columns[1:10], media.loc[row,"class1":"class9"], color = ["blue"] *5 + ["red"] *4)
    ax[(row-1)//3][(row-1)%3].title.set_text(f't={row}')
    ax[(row-1)//3][(row-1)%3].get_xaxis().set_visible(False)
plt.savefig("media-dist-all.png")
plt.show()

# %%
pos_cuts = pd.read_csv("../dados/output/cuts-oliveira-gouveia.csv")
neg_cuts = pd.read_csv("../dados/output/cuts-borges-gouveia.csv")

# %%
pos_cuts.head()
# Out:
#           after  before          cut          cut_vol vol_cut
# 0   7592.400000    9813  2220.600000        7403.4804     nil
# 1   8545.704025    9695  1149.295975  3831.7527815254     nil
# 2   9785.754447   11036  1250.245553  4168.3186736434     nil
# 3  12695.000000   12695     0.000000              nil     nil

# %%
neg_cuts.head()
# Out:
#           after  before          cut          cut_vol vol_cut
# 0   7592.400000    9813  2220.600000        7403.4804     nil
# 1   8669.611717    9687  1017.388283  3391.9725353716     nil
# 2  10498.653644   11302   803.346356  2678.3567522563     nil
# 3  13676.000000   13676     0.000000              nil     nil

# %%
comp=  pd.DataFrame()

comp["media"] =  neg_cuts["cut"].astype("int")[:-1]
comp["media_vol"] =  neg_cuts["cut_vol"][:-1].astype("float")
comp["Neg_vol_tree"] = comp["media_vol"].values /722
comp["Positivo"] =  pos_cuts["cut"].astype("int")[:-1]
comp["Positivo_vol"] =  pos_cuts["cut_vol"][:-1].astype("float")
comp["Pos_vol_tree"] = comp["Positivo_vol"] /722
comp.head()
# Out:
#    Negativo  Negativo_vol  Neg_vol_tree  Positivo  Positivo_vol  Pos_vol_tree
# 0      2220   7403.480400     10.254128      2220   7403.480400     10.254128
# 1      1017   3391.972535      4.698023      1149   3831.752782      5.307137
# 2       803   2678.356752      3.709635      1250   4168.318674      5.773295

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,6))
ax1.bar(range(2, 4), height = comp["media"][1:])
ax2.bar(range(2, 4), height = comp["Positivo"][1:])
plt.suptitle("Comparação dos cortes", fontdict ={"fontsize":18, "fontweight":"bold"})
ax1.set_title("media")
ax2.set_title("Positivo")
ax1.set_xticks([2, 3])
ax2.set_xticks([2, 3])
ax1.set_xlabel("Cortes")
ax2.set_xlabel("Cortes")
plt.savefig("cut-comp.png", dpi= 250)
plt.show()
